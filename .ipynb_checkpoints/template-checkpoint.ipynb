# %% [markdown]
# # Your Title Here
#
# **Name(s)**: Pratham Aggarwal
#
# **Website Link**: (your website link)

# %%
import pandas as pd
import numpy as np
from pathlib import Path
import plotly.express as px
pd.options.plotting.backend = 'plotly'
from dsc80_utils import *

# %% [markdown]
# ## Step 1: Introduction

# %%
# TODO
# data_dct = https://www.sciencedirect.com/science/article/pii/S2352340918307182
fp = Path('data') / 'outage.csv'
raw_df = pd.read_csv(fp, skiprows=5)

# %% [markdown]
# ## Step 2: Data Cleaning and Exploratory Data Analysis

# %%
# TODO
df = raw_df.copy(deep=True)
df.columns = [col.lower() for col in df.columns]
units = df.iloc[0]

df = df.iloc[1:].reset_index(drop=True)

new_columns = []
for col, unit in zip(df.columns, units):
    if pd.notna(unit):
        new_columns.append(f"{col} ({unit})")
    else:
        new_columns.append(col)

df.columns = new_columns
df = df.drop(columns = ['variables (Units)'])

# %%
#find cols which had nans
nan_cols = []
# Out:
#    obs    year  month u.s._state  ... areapct_uc (%) pct_land (%)  \
# 0  1.0  2011.0    7.0  Minnesota  ...            0.6  91.59266587
# 1  2.0  2014.0    5.0  Minnesota  ...            0.6  91.59266587
# 2  3.0  2010.0   10.0  Minnesota  ...            0.6  91.59266587
# 3  4.0  2012.0    6.0  Minnesota  ...            0.6  91.59266587
# 4  5.0  2015.0    7.0  Minnesota  ...            0.6  91.59266587
#
#   pct_water_tot (%) pct_water_inland (%)
# 0       8.407334131          5.478742983
# 1       8.407334131          5.478742983
# 2       8.407334131          5.478742983
# 3       8.407334131          5.478742983
# 4       8.407334131          5.478742983
#
# [5 rows x 56 columns]

# %%
import plotly.express as px

df_plot = df.copy()

df_plot['weather_group'] = df_plot['cause.category'].apply(
    lambda x: 'severe weather' if x == 'severe weather' else 'non-weather'
)

fig = px.violin(
    df_plot,
    x='weather_group',
    y='outage.duration (mins)',
    color='weather_group',
    title='Outage Duration by Weather Group'
)

fig.show()
# Out:
# <div>                            <div id="436594dc-fd8e-4b21-9746-f627a8d23ec0" class="plotly-graph-div" style="height:400px; width:600px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("436594dc-fd8e-4b21-9746-f627a8d23ec0")) {                    Plotly.newPlot(                        "436594dc-fd8e-4b21-9746-f627a8d23ec0",                        [{"alignmentgroup":"True","box":{"visible":false},"hovertemplate":"weather_group=%{x}\u003cbr\u003eoutage.duration (mins)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"severe weather","marker":{"color":"#1F77B4"},"name":"severe weather","offsetgroup":"severe weather","orientation":"v","scalegroup":"True","showlegend":true,"x":["severe weather","severe weather","severe weather","severe weather","severe weather","severe weather","severe weather","sev
# ...

# %% [markdown]
# ## Step 3: Assessment of Missingness

# %%
# TODO

# %% [markdown]
# ## Step 4: Hypothesis Testing

# %%
# TODO

# %% [markdown]
# ## Step 5: Framing a Prediction Problem

# %%
# TODO

# %% [markdown]
# ## Step 6: Baseline Model

# %%
# TODO

# %% [markdown]
# ## Step 7: Final Model

# %%
# TODO

# %% [markdown]
# ## Step 8: Fairness Analysis

# %%
# TODO
